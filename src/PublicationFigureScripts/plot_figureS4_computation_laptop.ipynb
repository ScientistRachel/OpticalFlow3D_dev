# %%
# Notebook SetUp
from calc_flow import process_flow
import re
import os
import tracemalloc
import timeit
from pathlib import Path
import pandas as pd
import tifffile as tf
import matplotlib.pyplot as plt
import numpy as np

#### Set up optical flow parameters
# Spatial smoothing (voxels)
xyzSig = 3
# Temporal smoothing (frames)
tSig = 1
# Lucas-Kanade neighborhood size (voxels)
wSig = 4

# Saving and loading
mainDir = 'X:\\Force Project\\PublicationData\\PerformanceTests'
mainDir = Path(mainDir)
program = 'Python-laptop'
savename = mainDir / 'PerformanceData_Python_Laptop.csv'

# %%
# 2D data in the 'OneTif' format

imDir = 'X:\\Force Project\\PublicationData\\PerformanceTests\\2D_OneTif'
fileType = 'OneTif'
spatialDimensions = 2
    
imNamePattern = re.compile('.*.tif')
files = os.listdir(imDir)
for imName in files:
    m = imNamePattern.fullmatch(imName)
    if m:
        print('FILE: ' + imName)

        meta = tf.TiffFile(Path(imDir) / imName)
        Ny = meta.pages[0].shape[0]
        Nx = meta.pages[0].shape[1]
        Nv = Nx*Ny
        del meta, Ny, Nx

        imName = imName.replace('.tif','')

        tracemalloc.start()

        t = timeit.timeit(lambda: process_flow(imDir,imName,fileType,spatialDimensions,xyzSig,tSig,wSig),'gc.enable()',number=10) # 10 matches what was done in MATLAB

        trsize, trpeak = tracemalloc.get_traced_memory()

        param = {'program': program,
                'imageDirectory': imDir,
                'imageName': imName,
                'processingType': fileType,
                'spatialDimensions': [spatialDimensions],
                'xyzSig': [xyzSig],
                'tiSig': [tSig],
                'wSig': [wSig],
                'TotalTime': [t],
                'PeakMemory': [trpeak],
                'Nvoxels': [Nv]}
        param = pd.DataFrame(param)

        param.to_csv(savename, index=False, mode='a',header=False)
        tracemalloc.reset_peak()

        print(' ') # Print a gap between files

print(' ') # Print a gap between folders
# Out:
# FILE: 20241107_U2OS_SGRLC_100Xoil_15mintimelapse_01_25plaser-slice7-1024-frames1-7.tif
# Note: regardless of input filenames, the first image = frame 0.
# If your file names start from 0, adjust indexing accordingly for reading the output files.
#
# 2025-05-20 14:22:50.090969 - No data will be saved for frame 0 to avoid edge effects
# 2025-05-20 14:22:50.091086 - No data will be saved for frame 1 to avoid edge effects
# 2025-05-20 14:22:50.091183 - No data will be saved for frame 2 to avoid edge effects
# 2025-05-20 14:22:50.167154 - Processing frame 3...
# 2025-05-20 14:22:52.713311 - Frame 3 saved.  Duration: 0:00:02.546145
# 2025-05-20 14:22:52.713775 - No data will be saved for frame 4 to avoid edge effects
# 2025-05-20 14:22:52.714053 - No data will be saved for frame 5 to avoid edge effects
# 2025-05-20 14:22:52.714315 - No data will be saved for frame 6 to avoid edge effects
# Note: regardless of input filenames, the first image = frame 0.
# If your file names start from 0, adjust indexing accordingly for reading the output files.
#
# 2025-05-20 14:22:52.830344 - No data will be saved for frame 0 to avoid edge effects
# 2025-05-20 14:22:52.830429 - No data will be saved for frame 1 to avoid edge effects
# 2025-05-20 14:22:52.830508 - No data will be saved for frame 2 to avoid edge effects
# 2025-05-20 14:22:52.871456 - Processing frame 3...
# 2025-05-20 14:22:54.509584 - Frame 3 saved.  Duration: 0:00:01.638125
# 2025-05-20 14:22:54.509946 - No data will be saved for frame 4 to avoid edge effects
# 2025-05-20 14:22:54.510127 - No data will be saved for frame 5 to avoid edge effects
# 2025-05-20 14:22:54.510283 - No data will be saved for frame 6 to avoid edge effects
# Note: regardless of input filenames, the first image = frame 0.
# If your file names start from 0, adjust indexing accordingly for reading the output files.
#
# 2025-05-20 14:22:54.637279 - No data will be saved for frame 0 to avoid edge effects
# 2025-05-20 14:22:54.637382 - No data will be saved for frame 1 to avoid edge effects
# 2025-05-20 14:22:54.637458 - No data will be saved for frame 2 to avoid edge effects
# 2025-05-20 14:22:54.689850 - Processing frame 3...
# 2025-05-20 14:22:56.245680 - Frame 3 saved.  Duration: 0:00:01.555826
# 2025-05-20 14:22:56.245968 - No data will be saved for frame 4 to avoid edge effects
# 2025-05-20 14:22:56.246111 - No data will be saved for frame 5 to avoid edge effects
# 2025-05-20 14:22:56.246249 - No data will be saved for frame 6 to avoid edge effects
# Note: regardless of input filenames, the first image = frame 0.
# If your file names start from 0, adjust indexing accordingly for reading the output files.
#
# 2025-05-20 14:22:56.344259 - No data will be saved for frame 0 to avoid edge effects
# 2025-05-20 14:22:56.344424 - No data will be saved for frame 1 to avoid edge effects
# 2025-05-20 14:22:56.344524 - No data will be saved for frame 2 to avoid edge effects
# 2025-05-20 14:22:56.387726 - Processing frame 3...
# 2025-05-20 14:22:58.135296 - Frame 3 saved.  Duration: 0:00:01.747581
# 2025-05-20 14:22:58.135646 - No data will be saved for frame 4 to avoid edge effects
# 2025-05-20 14:22:58.135843 - No data will be saved for frame 5 to avoid edge effects
# 2025-05-20 14:22:58.136020 - No data will be saved for frame 6 to avoid edge effects
# Note: regardless of input filenames, the first image = frame 0.
# If your file names start from 0, adjust indexing accordingly for reading the output files.
#
# 2025-05-20 14:22:58.234958 - No data will be saved for frame 0 to avoid edge effects
# 2025-05-20 14:22:58.235039 - No data will be saved for frame 1 to avoid edge effects
# 2025-05-20 14:22:58.235109 - No data will be saved for frame 2 to avoid edge effects
# 2025-05-20 14:22:58.283487 - Processing frame 3...
# 2025-05-20 14:22:59.755487 - Frame 3 saved.  Duration: 0:00:01.471989
# 2025-05-20 14:22:59.755850 - No data will be saved for frame 4 to avoid edge effects
# 2025-05-20 14:22:59.756060 - No data will be saved for frame 5 to avoid edge effects
# 2025-05-20 14:22:59.756268 - No data will be saved for frame 6 to avoid edge effects
# Note: regardless of input filenames, the first image = frame 0.
# If your file names start from 0, adjust indexing accordingly for reading the output files.
#
# 2025-05-20 14:22:59.883786 - No data will be saved for frame 0 to avoid edge effects
# 2025-05-20 14:22:59.883982 - No data will be saved for frame 1 to avoid edge effects
# 2025-05-20 14:22:59.884131 - No data will be saved for frame 2 to avoid edge effects
# 2025-05-20 14:22:59.928558 - Processing frame 3...
# 2025-05-20 14:23:01.730700 - Frame 3 saved.  Duration: 0:00:01.802131
# 2025-05-20 14:23:01.731120 - No data will be saved for frame 4 to avoid edge effects
# 2025-05-20 14:23:01.731374 - No data will be saved for frame 5 to avoid edge effects
# 2025-05-20 14:23:01.731557 - No data will be saved for frame 6 to avoid edge effects
# Note: regardless of input filenames, the first image = frame 0.
# If your file names start from 0, adjust indexing accordingly for reading the output files.
#
# 2025-05-20 14:23:01.867679 - No data will be saved for frame 0 to avoid edge effects
# 2025-05-20 14:23:01.867755 - No data will be saved for frame 1 to avoid edge effects
# 2025-05-20 14:23:01.867820 - No data will be saved for frame 2 to avoid edge effects
# 2025-05-20 14:23:01.914544 - Processing frame 3...
# 2025-05-20 14:23:03.632029 - Frame 3 saved.  Duration: 0:00:01.717462
# 2025-05-20 14:23:03.632504 - No data will be saved for frame 4 to avoid edge effects
# 2025-05-20 14:23:03.632740 - No data will be saved for frame 5 to avoid edge effects
# 2025-05-20 14:23:03.632959 - No data will be saved for frame 6 to avoid edge effects
# Note: regardless of input filenames, the first image = frame 0.
# If your file names start from 0, adjust indexing accordingly for reading the output files.
#
# 2025-05-20 14:23:03.752501 - No data will be saved for frame 0 to avoid edge effects
# 2025-05-20 14:23:03.752584 - No data will be saved for frame 1 to avoid edge effects
# 2025-05-20 14:23:03.752653 - No data will be saved for frame 2 to avoid edge effects
# 2025-05-20 14:23:03.814983 - Processing frame 3...
# 2025-05-20 14:23:05.548636 - Frame 3 saved.  Duration: 0:00:01.733649
# 2025-05-20 14:23:05.548905 - No data will be saved for frame 4 to avoid edge effects
# 2025-05-20 14:23:05.549043 - No data will be saved for frame 5 to avoid edge effects
# 2025-05-20 14:23:05.549167 - No data will be saved for frame 6 to avoid edge effects
# Note: regardless of input filenames, the first image = frame 0.
# If your file names start from 0, adjust indexing accordingly for reading the output files.
#
# 2025-05-20 14:23:05.666481 - No data will be saved for frame 0 to avoid edge effects
# 2025-05-20 14:23:05.666564 - No data will be saved for frame 1 to avoid edge effects
# 2025-05-20 14:23:05.666631 - No data will be saved for frame 2 to avoid edge effects
# 2025-05-20 14:23:05.705608 - Processing frame 3...
# 2025-05-20 14:23:07.277376 - Frame 3 saved.  Duration: 0:00:01.571761
# 2025-05-20 14:23:07.277656 - No data will be saved for frame 4 to avoid edge effects
# 2025-05-20 14:23:07.277813 - No data will be saved for frame 5 to avoid edge effects
# 2025-05-20 14:23:07.277962 - No data will be saved for frame 6 to avoid edge effects
# Note: regardless of input filenames, the first image = frame 0.
# If your file names start from 0, adjust indexing accordingly for reading the output files.
#
# 2025-05-20 14:23:07.395159 - No data will be saved for frame 0 to avoid edge effects
# 2025-05-20 14:23:07.395249 - No data will be saved for frame 1 to avoid edge effects
# 2025-05-20 14:23:07.395320 - No data will be saved for frame 2 to avoid edge effects
# 2025-05-20 14:23:07.465644 - Processing frame 3...
# 2025-05-20 14:23:09.034851 - Frame 3 saved.  Duration: 0:00:01.569175
# 2025-05-20 14:23:09.035527 - No data will be saved for frame 4 to avoid edge effects
# 2025-05-20 14:23:09.035948 - No data will be saved for frame 5 to avoid edge effects
# 2025-05-20 14:23:09.036287 - No data will be saved for frame 6 to avoid edge effects
#
# FILE: 20241107_U2OS_SGRLC_100Xoil_15mintimelapse_01_25plaser-slice7-512_frames1-7.tif
# Note: regardless of input filenames, the first image = frame 0.
# If your file names start from 0, adjust indexing accordingly for reading the output files.
#
# 2025-05-20 14:23:09.321001 - No data will be saved for frame 0 to avoid edge effects
# 2025-05-20 14:23:09.321081 - No data will be saved for frame 1 to avoid edge effects
# 2025-05-20 14:23:09.321146 - No data will be saved for frame 2 to avoid edge effects
# 2025-05-20 14:23:09.376783 - Processing frame 3...
# 2025-05-20 14:23:10.242339 - Frame 3 saved.  Duration: 0:00:00.865548
# 2025-05-20 14:23:10.242659 - No data will be saved for frame 4 to avoid edge effects
# 2025-05-20 14:23:10.242880 - No data will be saved for frame 5 to avoid edge effects
# 2025-05-20 14:23:10.243089 - No data will be saved for frame 6 to avoid edge effects
# Note: regardless of input filenames, the first image = frame 0.
# If your file names start from 0, adjust indexing accordingly for reading the output files.
#
# 2025-05-20 14:23:10.353315 - No data will be saved for frame 0 to avoid edge effects
# 2025-05-20 14:23:10.353391 - No data will be saved for frame 1 to avoid edge effects
# 2025-05-20 14:23:10.353459 - No data will be saved for frame 2 to avoid edge effects
# 2025-05-20 14:23:10.395161 - Processing frame 3...
# 2025-05-20 14:23:10.862832 - Frame 3 saved.  Duration: 0:00:00.467648
# 2025-05-20 14:23:10.863397 - No data will be saved for frame 4 to avoid edge effects
# 2025-05-20 14:23:10.863843 - No data will be saved for frame 5 to avoid edge effects
# 2025-05-20 14:23:10.864280 - No data will be saved for frame 6 to avoid edge effects
# Note: regardless of input filenames, the first image = frame 0.
# If your file names start from 0, adjust indexing accordingly for reading the output files.
#
# 2025-05-20 14:23:10.997699 - No data will be saved for frame 0 to avoid edge effects
# 2025-05-20 14:23:10.997866 - No data will be saved for frame 1 to avoid edge effects
# 2025-05-20 14:23:10.998022 - No data will be saved for frame 2 to avoid edge effects
# 2025-05-20 14:23:11.054320 - Processing frame 3...
# 2025-05-20 14:23:11.526817 - Frame 3 saved.  Duration: 0:00:00.472475
# 2025-05-20 14:23:11.527461 - No data will be saved for frame 4 to avoid edge effects
# 2025-05-20 14:23:11.527798 - No data will be saved for frame 5 to avoid edge effects
# 2025-05-20 14:23:11.528107 - No data will be saved for frame 6 to avoid edge effects
# Note: regardless of input filenames, the first image = frame 0.
# If your file names start from 0, adjust indexing accordingly for reading the output files.
#
# 2025-05-20 14:23:11.643333 - No data will be saved for frame 0 to avoid edge effects
# 2025-05-20 14:23:11.643404 - No data will be saved for frame 1 to avoid edge effects
# 2025-05-20 14:23:11.643464 - No data will be saved for frame 2 to avoid edge effects
# 2025-05-20 14:23:11.709586 - Processing frame 3...
# 2025-05-20 14:23:12.199946 - Frame 3 saved.  Duration: 0:00:00.490344
# 2025-05-20 14:23:12.200266 - No data will be saved for frame 4 to avoid edge effects
# 2025-05-20 14:23:12.200424 - No data will be saved for frame 5 to avoid edge effects
# 2025-05-20 14:23:12.200568 - No data will be saved for frame 6 to avoid edge effects
# Note: regardless of input filenames, the first image = frame 0.
# If your file names start from 0, adjust indexing accordingly for reading the output files.
#
# 2025-05-20 14:23:12.305712 - No data will be saved for frame 0 to avoid edge effects
# 2025-05-20 14:23:12.305860 - No data will be saved for frame 1 to avoid edge effects
# 2025-05-20 14:23:12.305999 - No data will be saved for frame 2 to avoid edge effects
# 2025-05-20 14:23:12.350289 - Processing frame 3...
# 2025-05-20 14:23:12.818281 - Frame 3 saved.  Duration: 0:00:00.467982
# 2025-05-20 14:23:12.818771 - No data will be saved for frame 4 to avoid edge effects
# 2025-05-20 14:23:12.819018 - No data will be saved for frame 5 to avoid edge effects
# 2025-05-20 14:23:12.819215 - No data will be saved for frame 6 to avoid edge effects
# Note: regardless of input filenames, the first image = frame 0.
# If your file names start from 0, adjust indexing accordingly for reading the output files.
#
# 2025-05-20 14:23:12.931612 - No data will be saved for frame 0 to avoid edge effects
# 2025-05-20 14:23:12.931751 - No data will be saved for frame 1 to avoid edge effects
# 2025-05-20 14:23:12.931878 - No data will be saved for frame 2 to avoid edge effects
# 2025-05-20 14:23:12.991777 - Processing frame 3...
# 2025-05-20 14:23:13.590872 - Frame 3 saved.  Duration: 0:00:00.599103
# 2025-05-20 14:23:13.591264 - No data will be saved for frame 4 to avoid edge effects
# 2025-05-20 14:23:13.591495 - No data will be saved for frame 5 to avoid edge effects
# 2025-05-20 14:23:13.591706 - No data will be saved for frame 6 to avoid edge effects
# Note: regardless of input filenames, the first image = frame 0.
# If your file names start from 0, adjust indexing accordingly for reading the output files.
#
# 2025-05-20 14:23:13.717517 - No data will be saved for frame 0 to avoid edge effects
# 2025-05-20 14:23:13.717605 - No data will be saved for frame 1 to avoid edge effects
# 2025-05-20 14:23:13.717705 - No data will be saved for frame 2 to avoid edge effects
# 2025-05-20 14:23:13.778133 - Processing frame 3...
# 2025-05-20 14:23:14.289877 - Frame 3 saved.  Duration: 0:00:00.511736
# 2025-05-20 14:23:14.290288 - No data will be saved for frame 4 to avoid edge effects
# 2025-05-20 14:23:14.290532 - No data will be saved for frame 5 to avoid edge effects
# 2025-05-20 14:23:14.290771 - No data will be saved for frame 6 to avoid edge effects
# Note: regardless of input filenames, the first image = frame 0.
# If your file names start from 0, adjust indexing accordingly for reading the output files.
#
# 2025-05-20 14:23:14.399304 - No data will be saved for frame 0 to avoid edge effects
# 2025-05-20 14:23:14.399460 - No data will be saved for frame 1 to avoid edge effects
# 2025-05-20 14:23:14.399644 - No data will be saved for frame 2 to avoid edge effects
# 2025-05-20 14:23:14.455791 - Processing frame 3...
# 2025-05-20 14:23:14.991916 - Frame 3 saved.  Duration: 0:00:00.536098
# 2025-05-20 14:23:14.992579 - No data will be saved for frame 4 to avoid edge effects
# 2025-05-20 14:23:14.992945 - No data will be saved for frame 5 to avoid edge effects
# 2025-05-20 14:23:14.993338 - No data will be saved for frame 6 to avoid edge effects
# Note: regardless of input filenames, the first image = frame 0.
# If your file names start from 0, adjust indexing accordingly for reading the output files.
#
# 2025-05-20 14:23:15.114626 - No data will be saved for frame 0 to avoid edge effects
# 2025-05-20 14:23:15.114855 - No data will be saved for frame 1 to avoid edge effects
# 2025-05-20 14:23:15.115074 - No data will be saved for frame 2 to avoid edge effects
# 2025-05-20 14:23:15.176740 - Processing frame 3...
# 2025-05-20 14:23:15.604461 - Frame 3 saved.  Duration: 0:00:00.427708
# 2025-05-20 14:23:15.604792 - No data will be saved for frame 4 to avoid edge effects
# 2025-05-20 14:23:15.604927 - No data will be saved for frame 5 to avoid edge effects
# 2025-05-20 14:23:15.605052 - No data will be saved for frame 6 to avoid edge effects
# Note: regardless of input filenames, the first image = frame 0.
# If your file names start from 0, adjust indexing accordingly for reading the output files.
#
# 2025-05-20 14:23:15.711646 - No data will be saved for frame 0 to avoid edge effects
# 2025-05-20 14:23:15.711714 - No data will be saved for frame 1 to avoid edge effects
# 2025-05-20 14:23:15.711780 - No data will be saved for frame 2 to avoid edge effects
# 2025-05-20 14:23:15.754847 - Processing frame 3...
# 2025-05-20 14:23:16.217744 - Frame 3 saved.  Duration: 0:00:00.462883
# 2025-05-20 14:23:16.218078 - No data will be saved for frame 4 to avoid edge effects
# 2025-05-20 14:23:16.218241 - No data will be saved for frame 5 to avoid edge effects
# 2025-05-20 14:23:16.218395 - No data will be saved for frame 6 to avoid edge effects

# %%
# 2D data in the 'SequenceT' format

imDir = 'X:\\Force Project\\PublicationData\\PerformanceTests\\2D_Sequence'
imName = '20241107_U2OS_SGRLC_100Xoil_15mintimelapse_01_25plaser-slice7_t.*'
fileType = 'SequenceT'
spatialDimensions = 2
    
meta = tf.TiffFile(Path(imDir) / '20241107_U2OS_SGRLC_100Xoil_15mintimelapse_01_25plaser-slice7_t0000.tif')
Ny = meta.pages[0].shape[0]
Nx = meta.pages[0].shape[1]
Nv = Nx*Ny
del meta, Ny, Nx

imName = imName.replace('.tif','')

tracemalloc.start()

t = timeit.timeit(lambda: process_flow(imDir,imName,fileType,spatialDimensions,xyzSig,tSig,wSig),'gc.enable()',number=10) # 10 matches what was done in MATLAB

trsize, trpeak = tracemalloc.get_traced_memory()

param = {'program': program,
        'imageDirectory': imDir,
        'imageName': imName,
        'processingType': fileType,
        'spatialDimensions': [spatialDimensions],
        'xyzSig': [xyzSig],
        'tiSig': [tSig],
        'wSig': [wSig],
        'TotalTime': [t],
        'PeakMemory': [trpeak],
        'Nvoxels': [Nv]}
param = pd.DataFrame(param)

param.to_csv(savename, index=False, mode='a',header=False)
tracemalloc.reset_peak()
# Out:
# Note: regardless of input filenames, the first image = frame 0.
# If your file names start from 0, adjust indexing accordingly for reading the output files.
#
# 2025-05-20 14:23:16.516394 - No data will be saved for frame 0 to avoid edge effects
# 2025-05-20 14:23:16.516479 - No data will be saved for frame 1 to avoid edge effects
# 2025-05-20 14:23:16.516549 - No data will be saved for frame 2 to avoid edge effects
# 2025-05-20 14:23:16.516672 - Processing frame 3...
# 2025-05-20 14:23:25.193404 - Frame 3 saved.  Duration: 0:00:08.676732
# 2025-05-20 14:23:25.193728 - No data will be saved for frame 4 to avoid edge effects
# 2025-05-20 14:23:25.193858 - No data will be saved for frame 5 to avoid edge effects
# 2025-05-20 14:23:25.193980 - No data will be saved for frame 6 to avoid edge effects
# Note: regardless of input filenames, the first image = frame 0.
# If your file names start from 0, adjust indexing accordingly for reading the output files.
#
# 2025-05-20 14:23:25.354993 - No data will be saved for frame 0 to avoid edge effects
# 2025-05-20 14:23:25.355135 - No data will be saved for frame 1 to avoid edge effects
# 2025-05-20 14:23:25.355257 - No data will be saved for frame 2 to avoid edge effects
# 2025-05-20 14:23:25.355471 - Processing frame 3...
# 2025-05-20 14:23:33.880626 - Frame 3 saved.  Duration: 0:00:08.525149
# 2025-05-20 14:23:33.880986 - No data will be saved for frame 4 to avoid edge effects
# 2025-05-20 14:23:33.881146 - No data will be saved for frame 5 to avoid edge effects
# 2025-05-20 14:23:33.881303 - No data will be saved for frame 6 to avoid edge effects
# Note: regardless of input filenames, the first image = frame 0.
# If your file names start from 0, adjust indexing accordingly for reading the output files.
#
# 2025-05-20 14:23:33.997755 - No data will be saved for frame 0 to avoid edge effects
# 2025-05-20 14:23:33.997835 - No data will be saved for frame 1 to avoid edge effects
# 2025-05-20 14:23:33.997902 - No data will be saved for frame 2 to avoid edge effects
# 2025-05-20 14:23:33.998011 - Processing frame 3...
# 2025-05-20 14:23:42.418438 - Frame 3 saved.  Duration: 0:00:08.420409
# 2025-05-20 14:23:42.418911 - No data will be saved for frame 4 to avoid edge effects
# 2025-05-20 14:23:42.419142 - No data will be saved for frame 5 to avoid edge effects
# 2025-05-20 14:23:42.419553 - No data will be saved for frame 6 to avoid edge effects
# Note: regardless of input filenames, the first image = frame 0.
# If your file names start from 0, adjust indexing accordingly for reading the output files.
#
# 2025-05-20 14:23:42.538262 - No data will be saved for frame 0 to avoid edge effects
# 2025-05-20 14:23:42.538445 - No data will be saved for frame 1 to avoid edge effects
# 2025-05-20 14:23:42.538606 - No data will be saved for frame 2 to avoid edge effects
# 2025-05-20 14:23:42.538866 - Processing frame 3...
# 2025-05-20 14:23:50.998900 - Frame 3 saved.  Duration: 0:00:08.460039
# 2025-05-20 14:23:50.999226 - No data will be saved for frame 4 to avoid edge effects
# 2025-05-20 14:23:50.999362 - No data will be saved for frame 5 to avoid edge effects
# 2025-05-20 14:23:50.999487 - No data will be saved for frame 6 to avoid edge effects
# Note: regardless of input filenames, the first image = frame 0.
# If your file names start from 0, adjust indexing accordingly for reading the output files.
#
# 2025-05-20 14:23:51.126682 - No data will be saved for frame 0 to avoid edge effects
# 2025-05-20 14:23:51.126939 - No data will be saved for frame 1 to avoid edge effects
# 2025-05-20 14:23:51.127201 - No data will be saved for frame 2 to avoid edge effects
# 2025-05-20 14:23:51.127565 - Processing frame 3...
# 2025-05-20 14:24:00.073972 - Frame 3 saved.  Duration: 0:00:08.946432
# 2025-05-20 14:24:00.074297 - No data will be saved for frame 4 to avoid edge effects
# 2025-05-20 14:24:00.074436 - No data will be saved for frame 5 to avoid edge effects
# 2025-05-20 14:24:00.074559 - No data will be saved for frame 6 to avoid edge effects
# Note: regardless of input filenames, the first image = frame 0.
# If your file names start from 0, adjust indexing accordingly for reading the output files.
#
# 2025-05-20 14:24:00.214513 - No data will be saved for frame 0 to avoid edge effects
# 2025-05-20 14:24:00.214777 - No data will be saved for frame 1 to avoid edge effects
# 2025-05-20 14:24:00.214891 - No data will be saved for frame 2 to avoid edge effects
# 2025-05-20 14:24:00.215057 - Processing frame 3...
# 2025-05-20 14:24:09.770099 - Frame 3 saved.  Duration: 0:00:09.555034
# 2025-05-20 14:24:09.770405 - No data will be saved for frame 4 to avoid edge effects
# 2025-05-20 14:24:09.770533 - No data will be saved for frame 5 to avoid edge effects
# 2025-05-20 14:24:09.770661 - No data will be saved for frame 6 to avoid edge effects
# Note: regardless of input filenames, the first image = frame 0.
# If your file names start from 0, adjust indexing accordingly for reading the output files.
#
# 2025-05-20 14:24:09.906141 - No data will be saved for frame 0 to avoid edge effects
# 2025-05-20 14:24:09.906290 - No data will be saved for frame 1 to avoid edge effects
# 2025-05-20 14:24:09.906431 - No data will be saved for frame 2 to avoid edge effects
# 2025-05-20 14:24:09.906656 - Processing frame 3...
# 2025-05-20 14:24:19.719815 - Frame 3 saved.  Duration: 0:00:09.813164
# 2025-05-20 14:24:19.720150 - No data will be saved for frame 4 to avoid edge effects
# 2025-05-20 14:24:19.720279 - No data will be saved for frame 5 to avoid edge effects
# 2025-05-20 14:24:19.720404 - No data will be saved for frame 6 to avoid edge effects
# Note: regardless of input filenames, the first image = frame 0.
# If your file names start from 0, adjust indexing accordingly for reading the output files.
#
# 2025-05-20 14:24:19.885036 - No data will be saved for frame 0 to avoid edge effects
# 2025-05-20 14:24:19.885250 - No data will be saved for frame 1 to avoid edge effects
# 2025-05-20 14:24:19.885448 - No data will be saved for frame 2 to avoid edge effects
# 2025-05-20 14:24:19.885764 - Processing frame 3...
# 2025-05-20 14:24:29.613269 - Frame 3 saved.  Duration: 0:00:09.727536
# 2025-05-20 14:24:29.613562 - No data will be saved for frame 4 to avoid edge effects
# 2025-05-20 14:24:29.613689 - No data will be saved for frame 5 to avoid edge effects
# 2025-05-20 14:24:29.613816 - No data will be saved for frame 6 to avoid edge effects
# Note: regardless of input filenames, the first image = frame 0.
# If your file names start from 0, adjust indexing accordingly for reading the output files.
#
# 2025-05-20 14:24:29.756093 - No data will be saved for frame 0 to avoid edge effects
# 2025-05-20 14:24:29.756236 - No data will be saved for frame 1 to avoid edge effects
# 2025-05-20 14:24:29.756355 - No data will be saved for frame 2 to avoid edge effects
# 2025-05-20 14:24:29.756542 - Processing frame 3...
# 2025-05-20 14:24:40.115625 - Frame 3 saved.  Duration: 0:00:10.359089
# 2025-05-20 14:24:40.115999 - No data will be saved for frame 4 to avoid edge effects
# 2025-05-20 14:24:40.116142 - No data will be saved for frame 5 to avoid edge effects
# 2025-05-20 14:24:40.116289 - No data will be saved for frame 6 to avoid edge effects
# Note: regardless of input filenames, the first image = frame 0.
# If your file names start from 0, adjust indexing accordingly for reading the output files.
#
# 2025-05-20 14:24:40.256161 - No data will be saved for frame 0 to avoid edge effects
# 2025-05-20 14:24:40.256364 - No data will be saved for frame 1 to avoid edge effects
# 2025-05-20 14:24:40.256549 - No data will be saved for frame 2 to avoid edge effects
# 2025-05-20 14:24:40.256849 - Processing frame 3...
# 2025-05-20 14:24:50.360930 - Frame 3 saved.  Duration: 0:00:10.104095
# 2025-05-20 14:24:50.361300 - No data will be saved for frame 4 to avoid edge effects
# 2025-05-20 14:24:50.361441 - No data will be saved for frame 5 to avoid edge effects
# 2025-05-20 14:24:50.361564 - No data will be saved for frame 6 to avoid edge effects

# %%
# 3D data in the 'OneTif' format

imDir = 'X:\\Force Project\\PublicationData\\PerformanceTests\\3D_OneTif'
fileType = 'OneTif'
spatialDimensions = 3

imNamePattern = re.compile('.*.tif')
files = os.listdir(imDir)
files = files[1:] # ignore the first file for memory reasons
for imName in files:
    m = imNamePattern.fullmatch(imName)
    if m:
        print('FILE: ' + imName)

        meta = tf.TiffFile(Path(imDir) / imName)
        Ny = meta.pages[0].shape[0]
        Nx = meta.pages[0].shape[1]
        Nz = meta.imagej_metadata["slices"]
        Nv = Nx*Ny*Nz
        del meta, Ny, Nx, Nz

        imName = imName.replace('.tif','')

        tracemalloc.start()

        t = timeit.timeit(lambda: process_flow(imDir,imName,fileType,spatialDimensions,xyzSig,tSig,wSig),'gc.enable()',number=10) # 10 matches what was done in MATLAB

        trsize, trpeak = tracemalloc.get_traced_memory()

        param = {'program': program,
                'imageDirectory': imDir,
                'imageName': imName,
                'processingType': fileType,
                'spatialDimensions': [spatialDimensions],
                'xyzSig': [xyzSig],
                'tiSig': [tSig],
                'wSig': [wSig],
                'TotalTime': [t],
                'PeakMemory': [trpeak],
                'Nvoxels': [Nv]}
        param = pd.DataFrame(param)

        param.to_csv(savename, index=False, mode='a',header=False)
        tracemalloc.reset_peak()

        print(' ') # Print a gap between files

print(' ') # Print a gap between folders
# Out:
# FILE: 20241107_U2OS_SGRLC_100Xoil_15mintimelapse_01_25plaser-z6-9_1024-frames1-7.tif
# Note: regardless of input filenames, the first image = frame 0.
# If your file names start from 0, adjust indexing accordingly for reading the output files.
#
# 2025-05-20 14:24:50.840912 - No data will be saved for frame 0 to avoid edge effects
# 2025-05-20 14:24:50.841133 - No data will be saved for frame 1 to avoid edge effects
# 2025-05-20 14:24:50.841328 - No data will be saved for frame 2 to avoid edge effects
# 2025-05-20 14:24:50.911487 - Processing frame 3...
# 2025-05-20 14:25:12.689566 - Frame 3 saved.  Duration: 0:00:21.778074
# 2025-05-20 14:25:12.689836 - No data will be saved for frame 4 to avoid edge effects
# 2025-05-20 14:25:12.689996 - No data will be saved for frame 5 to avoid edge effects
# 2025-05-20 14:25:12.690146 - No data will be saved for frame 6 to avoid edge effects
# Note: regardless of input filenames, the first image = frame 0.
# If your file names start from 0, adjust indexing accordingly for reading the output files.
#
# 2025-05-20 14:25:12.846080 - No data will be saved for frame 0 to avoid edge effects
# 2025-05-20 14:25:12.846148 - No data will be saved for frame 1 to avoid edge effects
# 2025-05-20 14:25:12.846205 - No data will be saved for frame 2 to avoid edge effects
# 2025-05-20 14:25:12.902880 - Processing frame 3...
# 2025-05-20 14:25:32.130213 - Frame 3 saved.  Duration: 0:00:19.227326
# 2025-05-20 14:25:32.130489 - No data will be saved for frame 4 to avoid edge effects
# 2025-05-20 14:25:32.130651 - No data will be saved for frame 5 to avoid edge effects
# 2025-05-20 14:25:32.130805 - No data will be saved for frame 6 to avoid edge effects
# Note: regardless of input filenames, the first image = frame 0.
# If your file names start from 0, adjust indexing accordingly for reading the output files.
#
# 2025-05-20 14:25:32.274169 - No data will be saved for frame 0 to avoid edge effects
# 2025-05-20 14:25:32.274269 - No data will be saved for frame 1 to avoid edge effects
# 2025-05-20 14:25:32.274363 - No data will be saved for frame 2 to avoid edge effects
# 2025-05-20 14:25:32.332842 - Processing frame 3...
# 2025-05-20 14:25:51.646080 - Frame 3 saved.  Duration: 0:00:19.313238
# 2025-05-20 14:25:51.646404 - No data will be saved for frame 4 to avoid edge effects
# 2025-05-20 14:25:51.646576 - No data will be saved for frame 5 to avoid edge effects
# 2025-05-20 14:25:51.646743 - No data will be saved for frame 6 to avoid edge effects
# Note: regardless of input filenames, the first image = frame 0.
# If your file names start from 0, adjust indexing accordingly for reading the output files.
#
# 2025-05-20 14:25:51.788050 - No data will be saved for frame 0 to avoid edge effects
# 2025-05-20 14:25:51.788131 - No data will be saved for frame 1 to avoid edge effects
# 2025-05-20 14:25:51.788205 - No data will be saved for frame 2 to avoid edge effects
# 2025-05-20 14:25:51.844851 - Processing frame 3...
# 2025-05-20 14:26:11.836277 - Frame 3 saved.  Duration: 0:00:19.991439
# 2025-05-20 14:26:11.836561 - No data will be saved for frame 4 to avoid edge effects
# 2025-05-20 14:26:11.836728 - No data will be saved for frame 5 to avoid edge effects
# 2025-05-20 14:26:11.836890 - No data will be saved for frame 6 to avoid edge effects
# Note: regardless of input filenames, the first image = frame 0.
# If your file names start from 0, adjust indexing accordingly for reading the output files.
#
# 2025-05-20 14:26:11.965382 - No data will be saved for frame 0 to avoid edge effects
# 2025-05-20 14:26:11.965548 - No data will be saved for frame 1 to avoid edge effects
# 2025-05-20 14:26:11.965744 - No data will be saved for frame 2 to avoid edge effects
# 2025-05-20 14:26:12.032417 - Processing frame 3...
# 2025-05-20 14:26:32.421825 - Frame 3 saved.  Duration: 0:00:20.389395
# 2025-05-20 14:26:32.422101 - No data will be saved for frame 4 to avoid edge effects
# 2025-05-20 14:26:32.422241 - No data will be saved for frame 5 to avoid edge effects
# 2025-05-20 14:26:32.422363 - No data will be saved for frame 6 to avoid edge effects
# Note: regardless of input filenames, the first image = frame 0.
# If your file names start from 0, adjust indexing accordingly for reading the output files.
#
# 2025-05-20 14:26:32.550325 - No data will be saved for frame 0 to avoid edge effects
# 2025-05-20 14:26:32.550433 - No data will be saved for frame 1 to avoid edge effects
# 2025-05-20 14:26:32.550522 - No data will be saved for frame 2 to avoid edge effects
# 2025-05-20 14:26:32.601200 - Processing frame 3...
# 2025-05-20 14:26:53.075462 - Frame 3 saved.  Duration: 0:00:20.474256
# 2025-05-20 14:26:53.075764 - No data will be saved for frame 4 to avoid edge effects
# 2025-05-20 14:26:53.075927 - No data will be saved for frame 5 to avoid edge effects
# 2025-05-20 14:26:53.076077 - No data will be saved for frame 6 to avoid edge effects
# Note: regardless of input filenames, the first image = frame 0.
# If your file names start from 0, adjust indexing accordingly for reading the output files.
#
# 2025-05-20 14:26:53.196897 - No data will be saved for frame 0 to avoid edge effects
# 2025-05-20 14:26:53.196975 - No data will be saved for frame 1 to avoid edge effects
# 2025-05-20 14:26:53.197085 - No data will be saved for frame 2 to avoid edge effects
# 2025-05-20 14:26:53.253777 - Processing frame 3...
# 2025-05-20 14:27:12.999462 - Frame 3 saved.  Duration: 0:00:19.745676
# 2025-05-20 14:27:12.999755 - No data will be saved for frame 4 to avoid edge effects
# 2025-05-20 14:27:12.999911 - No data will be saved for frame 5 to avoid edge effects
# 2025-05-20 14:27:13.000062 - No data will be saved for frame 6 to avoid edge effects
# Note: regardless of input filenames, the first image = frame 0.
# If your file names start from 0, adjust indexing accordingly for reading the output files.
#
# 2025-05-20 14:27:13.135142 - No data will be saved for frame 0 to avoid edge effects
# 2025-05-20 14:27:13.135213 - No data will be saved for frame 1 to avoid edge effects
# 2025-05-20 14:27:13.135270 - No data will be saved for frame 2 to avoid edge effects
# 2025-05-20 14:27:13.185891 - Processing frame 3...
# 2025-05-20 14:27:33.059902 - Frame 3 saved.  Duration: 0:00:19.874002
# 2025-05-20 14:27:33.060206 - No data will be saved for frame 4 to avoid edge effects
# 2025-05-20 14:27:33.060365 - No data will be saved for frame 5 to avoid edge effects
# 2025-05-20 14:27:33.060519 - No data will be saved for frame 6 to avoid edge effects
# Note: regardless of input filenames, the first image = frame 0.
# If your file names start from 0, adjust indexing accordingly for reading the output files.
#
# 2025-05-20 14:27:33.193676 - No data will be saved for frame 0 to avoid edge effects
# 2025-05-20 14:27:33.193783 - No data will be saved for frame 1 to avoid edge effects
# 2025-05-20 14:27:33.193867 - No data will be saved for frame 2 to avoid edge effects
# 2025-05-20 14:27:33.262113 - Processing frame 3...
# 2025-05-20 14:27:53.234740 - Frame 3 saved.  Duration: 0:00:19.972623
# 2025-05-20 14:27:53.235007 - No data will be saved for frame 4 to avoid edge effects
# 2025-05-20 14:27:53.235166 - No data will be saved for frame 5 to avoid edge effects
# 2025-05-20 14:27:53.235309 - No data will be saved for frame 6 to avoid edge effects
# Note: regardless of input filenames, the first image = frame 0.
# If your file names start from 0, adjust indexing accordingly for reading the output files.
#
# 2025-05-20 14:27:53.364249 - No data will be saved for frame 0 to avoid edge effects
# 2025-05-20 14:27:53.364372 - No data will be saved for frame 1 to avoid edge effects
# 2025-05-20 14:27:53.364482 - No data will be saved for frame 2 to avoid edge effects
# 2025-05-20 14:27:53.417067 - Processing frame 3...
# 2025-05-20 14:28:14.371124 - Frame 3 saved.  Duration: 0:00:20.954065
# 2025-05-20 14:28:14.371411 - No data will be saved for frame 4 to avoid edge effects
# 2025-05-20 14:28:14.371552 - No data will be saved for frame 5 to avoid edge effects
# 2025-05-20 14:28:14.371684 - No data will be saved for frame 6 to avoid edge effects
#
# FILE: 20241107_U2OS_SGRLC_100Xoil_15mintimelapse_01_25plaser-z6-9_512-frames1-7.tif
# Note: regardless of input filenames, the first image = frame 0.
# If your file names start from 0, adjust indexing accordingly for reading the output files.
#
# 2025-05-20 14:28:14.802008 - No data will be saved for frame 0 to avoid edge effects
# 2025-05-20 14:28:14.802129 - No data will be saved for frame 1 to avoid edge effects
# 2025-05-20 14:28:14.802238 - No data will be saved for frame 2 to avoid edge effects
# 2025-05-20 14:28:14.870689 - Processing frame 3...
# 2025-05-20 14:28:20.790139 - Frame 3 saved.  Duration: 0:00:05.919423
# 2025-05-20 14:28:20.790550 - No data will be saved for frame 4 to avoid edge effects
# 2025-05-20 14:28:20.790913 - No data will be saved for frame 5 to avoid edge effects
# 2025-05-20 14:28:20.791430 - No data will be saved for frame 6 to avoid edge effects
# Note: regardless of input filenames, the first image = frame 0.
# If your file names start from 0, adjust indexing accordingly for reading the output files.
#
# 2025-05-20 14:28:20.925038 - No data will be saved for frame 0 to avoid edge effects
# 2025-05-20 14:28:20.925102 - No data will be saved for frame 1 to avoid edge effects
# 2025-05-20 14:28:20.925162 - No data will be saved for frame 2 to avoid edge effects
# 2025-05-20 14:28:20.977775 - Processing frame 3...
# 2025-05-20 14:28:25.991910 - Frame 3 saved.  Duration: 0:00:05.014101
# 2025-05-20 14:28:25.992332 - No data will be saved for frame 4 to avoid edge effects
# 2025-05-20 14:28:25.992622 - No data will be saved for frame 5 to avoid edge effects
# 2025-05-20 14:28:25.992904 - No data will be saved for frame 6 to avoid edge effects
# Note: regardless of input filenames, the first image = frame 0.
# If your file names start from 0, adjust indexing accordingly for reading the output files.
#
# 2025-05-20 14:28:26.148301 - No data will be saved for frame 0 to avoid edge effects
# 2025-05-20 14:28:26.148427 - No data will be saved for frame 1 to avoid edge effects
# 2025-05-20 14:28:26.148543 - No data will be saved for frame 2 to avoid edge effects
# 2025-05-20 14:28:26.200343 - Processing frame 3...
# 2025-05-20 14:28:31.064074 - Frame 3 saved.  Duration: 0:00:04.863724
# 2025-05-20 14:28:31.064411 - No data will be saved for frame 4 to avoid edge effects
# 2025-05-20 14:28:31.064672 - No data will be saved for frame 5 to avoid edge effects
# 2025-05-20 14:28:31.064929 - No data will be saved for frame 6 to avoid edge effects
# Note: regardless of input filenames, the first image = frame 0.
# If your file names start from 0, adjust indexing accordingly for reading the output files.
#
# 2025-05-20 14:28:31.215882 - No data will be saved for frame 0 to avoid edge effects
# 2025-05-20 14:28:31.215975 - No data will be saved for frame 1 to avoid edge effects
# 2025-05-20 14:28:31.216054 - No data will be saved for frame 2 to avoid edge effects
# 2025-05-20 14:28:31.262876 - Processing frame 3...
# 2025-05-20 14:28:36.929111 - Frame 3 saved.  Duration: 0:00:05.666226
# 2025-05-20 14:28:36.929449 - No data will be saved for frame 4 to avoid edge effects
# 2025-05-20 14:28:36.929663 - No data will be saved for frame 5 to avoid edge effects
# 2025-05-20 14:28:36.929872 - No data will be saved for frame 6 to avoid edge effects
# Note: regardless of input filenames, the first image = frame 0.
# If your file names start from 0, adjust indexing accordingly for reading the output files.
#
# 2025-05-20 14:28:37.056034 - No data will be saved for frame 0 to avoid edge effects
# 2025-05-20 14:28:37.056100 - No data will be saved for frame 1 to avoid edge effects
# 2025-05-20 14:28:37.056158 - No data will be saved for frame 2 to avoid edge effects
# 2025-05-20 14:28:37.113579 - Processing frame 3...
# 2025-05-20 14:28:42.743379 - Frame 3 saved.  Duration: 0:00:05.629802
# 2025-05-20 14:28:42.743734 - No data will be saved for frame 4 to avoid edge effects
# 2025-05-20 14:28:42.743919 - No data will be saved for frame 5 to avoid edge effects
# 2025-05-20 14:28:42.744097 - No data will be saved for frame 6 to avoid edge effects
# Note: regardless of input filenames, the first image = frame 0.
# If your file names start from 0, adjust indexing accordingly for reading the output files.
#
# 2025-05-20 14:28:42.952246 - No data will be saved for frame 0 to avoid edge effects
# 2025-05-20 14:28:42.952326 - No data will be saved for frame 1 to avoid edge effects
# 2025-05-20 14:28:42.952393 - No data will be saved for frame 2 to avoid edge effects
# 2025-05-20 14:28:42.999345 - Processing frame 3...
# 2025-05-20 14:28:48.981432 - Frame 3 saved.  Duration: 0:00:05.982081
# 2025-05-20 14:28:48.981697 - No data will be saved for frame 4 to avoid edge effects
# 2025-05-20 14:28:48.981852 - No data will be saved for frame 5 to avoid edge effects
# 2025-05-20 14:28:48.982004 - No data will be saved for frame 6 to avoid edge effects
# Note: regardless of input filenames, the first image = frame 0.
# If your file names start from 0, adjust indexing accordingly for reading the output files.
#
# 2025-05-20 14:28:49.189067 - No data will be saved for frame 0 to avoid edge effects
# 2025-05-20 14:28:49.189139 - No data will be saved for frame 1 to avoid edge effects
# 2025-05-20 14:28:49.189200 - No data will be saved for frame 2 to avoid edge effects
# 2025-05-20 14:28:49.237957 - Processing frame 3...
# 2025-05-20 14:28:54.432958 - Frame 3 saved.  Duration: 0:00:05.194994
# 2025-05-20 14:28:54.433302 - No data will be saved for frame 4 to avoid edge effects
# 2025-05-20 14:28:54.433508 - No data will be saved for frame 5 to avoid edge effects
# 2025-05-20 14:28:54.433697 - No data will be saved for frame 6 to avoid edge effects
# Note: regardless of input filenames, the first image = frame 0.
# If your file names start from 0, adjust indexing accordingly for reading the output files.
#
# 2025-05-20 14:28:54.534666 - No data will be saved for frame 0 to avoid edge effects
# 2025-05-20 14:28:54.534747 - No data will be saved for frame 1 to avoid edge effects
# 2025-05-20 14:28:54.534823 - No data will be saved for frame 2 to avoid edge effects
# 2025-05-20 14:28:54.583726 - Processing frame 3...
# 2025-05-20 14:29:00.108490 - Frame 3 saved.  Duration: 0:00:05.524740
# 2025-05-20 14:29:00.109159 - No data will be saved for frame 4 to avoid edge effects
# 2025-05-20 14:29:00.109420 - No data will be saved for frame 5 to avoid edge effects
# 2025-05-20 14:29:00.109647 - No data will be saved for frame 6 to avoid edge effects
# Note: regardless of input filenames, the first image = frame 0.
# If your file names start from 0, adjust indexing accordingly for reading the output files.
#
# 2025-05-20 14:29:00.216522 - No data will be saved for frame 0 to avoid edge effects
# 2025-05-20 14:29:00.216594 - No data will be saved for frame 1 to avoid edge effects
# 2025-05-20 14:29:00.216653 - No data will be saved for frame 2 to avoid edge effects
# 2025-05-20 14:29:00.265447 - Processing frame 3...
# 2025-05-20 14:29:05.609500 - Frame 3 saved.  Duration: 0:00:05.344028
# 2025-05-20 14:29:05.609870 - No data will be saved for frame 4 to avoid edge effects
# 2025-05-20 14:29:05.610049 - No data will be saved for frame 5 to avoid edge effects
# 2025-05-20 14:29:05.610207 - No data will be saved for frame 6 to avoid edge effects
# Note: regardless of input filenames, the first image = frame 0.
# If your file names start from 0, adjust indexing accordingly for reading the output files.
#
# 2025-05-20 14:29:05.718841 - No data will be saved for frame 0 to avoid edge effects
# 2025-05-20 14:29:05.718950 - No data will be saved for frame 1 to avoid edge effects
# 2025-05-20 14:29:05.719050 - No data will be saved for frame 2 to avoid edge effects
# 2025-05-20 14:29:05.775617 - Processing frame 3...
# 2025-05-20 14:29:11.021550 - Frame 3 saved.  Duration: 0:00:05.245935
# 2025-05-20 14:29:11.021887 - No data will be saved for frame 4 to avoid edge effects
# 2025-05-20 14:29:11.022111 - No data will be saved for frame 5 to avoid edge effects
# 2025-05-20 14:29:11.022334 - No data will be saved for frame 6 to avoid edge effects

# %%
# 3D data in the 'SequenceT' format

# imDir = 'X:\\Force Project\\PublicationData\\PerformanceTests\\3D_Sequence'
# imName = 'scan_Cam1_ch0_tile0_t.*_deskew_after_decon'
# fileType = 'SequenceT'
# spatialDimensions = 3
    
# meta = tf.TiffFile(Path(imDir) / 'scan_Cam1_ch0_tile0_t0000_deskew_after_decon.tif')
# Ny = meta.pages[0].shape[0]
# Nx = meta.pages[0].shape[1]
# Nz = len(meta.pages)
# Nv = Nx*Ny*Nz
# del meta, Ny, Nx, Nz

# imName = imName.replace('.tif','')

# tracemalloc.start()

# t = timeit.timeit(lambda: process_flow(imDir,imName,fileType,spatialDimensions,xyzSig,tSig,wSig),'gc.enable()',number=10) # 10 matches what was done in MATLAB

# trsize, trpeak = tracemalloc.get_traced_memory()

# param = {'program': program,
#         'imageDirectory': imDir,
#         'imageName': imName,
#         'processingType': fileType,
#         'spatialDimensions': [spatialDimensions],
#         'xyzSig': [xyzSig],
#         'tiSig': [tSig],
#         'wSig': [wSig],
#         'TotalTime': [t],
#         'PeakMemory': [trpeak],
#         'Nvoxels': [Nv]}
# param = pd.DataFrame(param)

# param.to_csv(savename, index=False, mode='a',header=False)
# tracemalloc.reset_peak()

# %%
# m = pd.read_csv(mainDir / 'PerformanceData_MATLAB_workstation.csv')
# p = pd.read_csv(savename)

# print(m.columns)
# print(p.columns)

# mSlice = m.loc[:,['imageName','TotalTime','PeakMem','Nvoxels']]
# mMeans = mSlice.groupby('imageName').mean()

# p = p.sort_values(by='Nvoxels')
# mMeans = mMeans.sort_values(by='Nvoxels')

# %%
# fig, ax = plt.subplots()
# fig.set_figwidth(8)
# fig.set_figheight(6)

# plt.rcParams.update({'font.size': 16}) # Set global font size

# plt.plot(p.loc[:,'Nvoxels'],p.loc[:,'TotalTime']/60/10,'s',label="Python",markersize=8,color="#306998") # Divide by 10 for the number of iterations
# plt.plot(mMeans.loc[:,'Nvoxels'],mMeans.loc[:,'TotalTime']/60,'o',label="MATLAB",markersize=8,color="#fd4e06")

# # Fits for a rough illustration of the trend
# pm = np.polyfit(mMeans.loc[:,'Nvoxels'],mMeans.loc[:,'TotalTime'],2)
# xPlot = np.logspace(5.3,9.1,100)
# yPlot = np.polyval(pm,xPlot)
# plt.plot(xPlot,yPlot/60,'--',color="#fe8452",zorder=0,linewidth=1)

# pm = np.polyfit(p.loc[:,'Nvoxels'],p.loc[:,'TotalTime']/10,2)
# xPlot = np.logspace(5.3,9.1,100)
# yPlot = np.polyval(pm,xPlot)
# plt.plot(xPlot,yPlot/60,'--',color="#4e90c7",zorder=0,linewidth=1)

# ax.set_xscale('log')
# # ax.set_yscale('log')

# ax.set_xlabel('Voxels')
# ax.set_ylabel('Processing Time (min)')

# ax.spines['top'].set_visible(False)
# ax.spines['right'].set_visible(False)
# # ax.spines['bottom'].set_visible(False)
# # ax.spines['left'].set_visible(False)

# plt.legend()

# # Save 
# plt.savefig(mainDir / 'ProcessingTime_Python_and_MATLAB.png', dpi=300, bbox_inches='tight')
# # Show
# plt.show()

# %%
# fig, ax = plt.subplots()
# fig.set_figwidth(8)
# fig.set_figheight(6)

# plt.rcParams.update({'font.size': 16}) # Set global font size

# plt.plot(p.loc[:,'Nvoxels'],p.loc[:,'PeakMem']/1024**3,'s',label="Python",markersize=8,color="#306998") # Divide by 10 for the number of iterations
# plt.plot(mMeans.loc[:,'Nvoxels'],mMeans.loc[:,'PeakMem']/1024**3,'o',label="MATLAB",markersize=8,color="#fd4e06")

# # Fits for a rough illustration of the trend
# pm = np.polyfit(mMeans.loc[:,'Nvoxels'],mMeans.loc[:,'PeakMem']/1024**3,2)
# xPlot = np.logspace(5.3,9.1,100)
# yPlot = np.polyval(pm,xPlot)
# plt.plot(xPlot,yPlot,'--',color="#fe8452",zorder=0,linewidth=1)

# pm = np.polyfit(p.loc[:,'Nvoxels'],p.loc[:,'PeakMem']/1024**3,2)
# xPlot = np.logspace(5.3,9.1,100)
# yPlot = np.polyval(pm,xPlot)
# plt.plot(xPlot,yPlot,'--',color="#4e90c7",zorder=0,linewidth=1)

# ax.set_xscale('log')
# # ax.set_yscale('log')

# ax.set_xlabel('Voxels')
# ax.set_ylabel('Peak Memory Usage (GB)')

# ax.spines['top'].set_visible(False)
# ax.spines['right'].set_visible(False)
# # ax.spines['bottom'].set_visible(False)
# # ax.spines['left'].set_visible(False)

# plt.legend()

# # Save 
# plt.savefig(mainDir / 'MemoryUsage_Python_and_MATLAB.png', dpi=300, bbox_inches='tight')
# # Show
# plt.show()
